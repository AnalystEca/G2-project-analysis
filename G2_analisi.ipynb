# %%
# FASE DI PLAN
# Importare framework python necessari: Numpy, Pandas, Seaborn
# Importare il database in formato .csv scaricato da https://oracleselixir.com/
# Definire le domande chiave

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 1 - Andamento generale del team
# **Obiettivo:** capire se e quando il team vince o perde più spesso.
# * Qual è il win rate complessivo dei G2 nel periodo analizzato?
# * Il win rate cambia nel tempo? (split, mese, patch)
# * Esistono streak di vittorie o sconfitte significative?
# * Le sconfitte arrivano più spesso:
#     * dopo una vittoria?
#     * dopo una serie di vittorie?
# * I G2 performano meglio:
#     * in early split o late split?
#     * in BO1 vs BO3/BO5 (se disponibili)?
#
# **Insight tipico: stabilità vs volatilità del team.**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 2 - Early Game → Mid Game → Late Game
# **Obiettivo:** capire quando i G2 costruiscono vantaggio o perdono la partita.
#
# #### Early game (0–15 min)
# * I G2 ottengono più spesso: (come sono collegati questi obiettivi a vittorie e sconfitte?)
#     * First Blood
#     * First Tower
#     * First Dragon
#     * Herald
#     * Void Grubs
# * Qual è il gold difference @15 medio nelle vittorie vs sconfitte?
# * Quanto l’early game predice la vittoria finale?
#
# #### Mid game (15–25 min)
# * Il controllo degli obiettivi (draghi, herald, torri) nel mid game è correlato alla vittoria?
# * I G2 perdono partite anche con vantaggio a metà partita?
#
# #### Late game (25+ min)
# * Il winrate dei G2 in late game è alto o basso?
# * Le sconfitte arrivano piu spesso:
#     * per errori singoli
#     * per scaling inferiore
#
# **Insight tipico: team da early snowball o da macro/late game.**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 3 - Draft & Champion Select
# **Obiettivo:** scoprire pattern nascosti nella fase di draft.
# * Qual è il win rate per champion giocati dai G2
# * Esistono:
#     * champion overperformanti?
#     * champion trappola (pick frequenti ma poco vincenti)?
# * I G2 vincono di piu quando:
#     * ha scaling composition?
#     * ha early aggression
# * Qual è il win rate blue side vs red side?
# * Ci sono ban ricorrenti nelle vittorie?
# * I G2 perdono piu spesso quando:
#     * un ruolo specifico subisce un target ban?
#     * sono costretti a draftare fuori comfort?
#
# **Insight tipico: draft identity del team.**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 4 - Performance individuali
# **Obiettivo:** capire l'impatto dei singoli giocatori.
# * Qual è il KDA medio di ogni giocatore nelle vittorie e nelle sconfitte?
# * Quali sono le statistiche medie dei giocatori rispetto a quelle degli altri partecipanti al torneo?
# * Esistono giocatori che:
#     * performano bene anche nelle sconfitte?
#     * hanno forte impatto solo nelle vittorie
# * I G2 vincono più spesso quando una specifica lane è in vantaggio?
# * Quali sono:
#     * gold share per player nelle vittorie?
#     * damage share per player nelle vittorie
#
# **Insight tipico: carry dependency o team balance.**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 5 - Obiettivi neutrali e macro decision-making
# **Obiettivo:** analizzare la qualità delle decisioni macro.
# * Qual è il win rate quando i G2:
#     * prendono più draghi
#     * prendono il Baron Nashor
# * I G2 perdono partite:
#     * dopo Baron Throw?
#     * dopo fight persi vicino a obiettivi?
# * Qual è la conversion rate Baron → torri → vittoria?
# * I G2 tendono a:
#     * forzare fight?
#     * giocare per macro e vision?
#
# **Insight tipico: macro disciplinata vs over-aggression.**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 6 - Vision e Map control
# **Obiettivo:** Misurare controllo mappa e informazioni.
# * Vision score medio in vittorie vs sconfitte
# * I G2 vincono più spesso quando hanno vantaggio visione costante?
# * Quali ruoli contribuiscono di più alla visione?
# * Esiste un threshold minimo di vision oltre il quale il win rate sale?
#
# **Insight tipico: struttura e controllo del ritmo**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 7 - Errori e segnali di sconfitta
# **Obiettivo:** Identificare warning signs
# * Quali metriche sono segnali che anticipano la sconfitta?
#     * gold deficit @15
#     * early deaths
#     * zero draghi
# * Esistono pattern ripetuti nelle sconfitte?
#     * fight persi 5v5
#     * side lane collapse
# * I G2 perdono piu spesso partite lunghe o corte?
# **Insight tipico: quando la partita "scappa di mano"**

# %% [markdown]
# ### DOMANDE CHIAVE - MACRO GRUPPO 8 - Analisi predittiva (step avanzato)
# **Obiettivo:** passare da predizione a previsione
# * Quali variabili spiegano meglio la vittoria?
# * È possibile costruire un modello predittivo win/loss?
# * Il modello sbaglia più spesso
#     * in draft
#     * in late game
#
# **Insight tipico:** data driven coaching
